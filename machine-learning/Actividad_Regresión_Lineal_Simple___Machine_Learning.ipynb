# %%
# ------------------ ACTIVIDAD REGRESIÓN LINEAL SIMPLE--------------------------- #
#-------------------------------------------------------------------------------- #


# CARGAMOS EL DATASET Y PRINTEAMOS SUS PRIMERAS FILAS
import seaborn as sns
df = sns.load_dataset("mpg")
print(df.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# ----------------- EXPLORACIÓN INICIAL --------------------------------- #

# CARGAMOS EL ESQUELETO DE CÓDIGO SUGERIDO

# PRIMERO LLAMAMOS A LAS LIBRERÍAS & A Sklearn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# CARGAMOS LOS DATOS DEL DATASET EN UN OBJETO "df"

df = sns.load_dataset("mpg")

# ELEGIMOS ÚNICAMENTE LAS VARIABLES QUE VAMOS A USAR

df = df[["weight", "mpg"]].dropna()

# %%
# VERIFICAMOS QUE NO HAYAN NA's

print(df.isnull().sum())
# Out:
# weight    0
# mpg       0
# dtype: int64

# %% [markdown]
# **NO HAY NINGÚN VALOR FALTANTE**

# %%
# VERIFICAMOS CUANTAS OBSERVACIONES TENEMOS
print(f"El DataFrame tiene {len(df)} observaciones (filas).")
# Out:
# El DataFrame tiene 398 observaciones (filas).

# %%
# TIPOS DE DATOS DEL DATAFRAME
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  398 non-null    int64
#  1   mpg     398 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 6.3 KB

# %% [markdown]
# **weight: int (números enteros)**
#
# **mpg: float (números con coma)**

# %%
# PRINTEAMOS LAS PRIMERAS CINCO FILAS DEL DATASET
print("Primeras 5 filas del DataFrame actual:")
display(df.head())
# Out:
# Primeras 5 filas del DataFrame actual:
#    weight   mpg
# 0    3504  18.0
# 1    3693  15.0
# 2    3436  18.0
# 3    3433  16.0
# 4    3449  17.0

# %%
# VERIFICAMOS LAS ESTADÍATICAS BÁSICAS DE NUESTRO DATASET
print("Estadísticas descriptivas básicas:")
display(df.describe())
# Out:
# Estadísticas descriptivas básicas:
#             weight         mpg
# count   398.000000  398.000000
# mean   2970.424623   23.514573
# std     846.841774    7.815984
# min    1613.000000    9.000000
# 25%    2223.750000   17.500000
# 50%    2803.500000   23.000000
# 75%    3608.000000   29.000000
# max    5140.000000   46.600000

# %%
# CONSTRUIMOS UN SCATTER PLOT
plt.figure(figsize=(10, 6))
sns.scatterplot(x='weight', y='mpg', data=df)
plt.title('Relación entre el Peso (weight) y el Consumo de Combustible (mpg)')
plt.xlabel('Peso (weight)')
plt.ylabel('Millas por Galón (mpg)')
plt.grid(True)
plt.show()

# %% [markdown]
# **¿La relación parece positiva o negativa?**
#
# La relación parece negativa, inversamente proporcional
#
#
# **• ¿La relación parece aproximadamente lineal?**
#
# No, la relación parece ser lineal
#
#
# **• ¿Se observan posibles valores atípicos? **
#
# Cuando el peso es de 3000 y mpg>35
